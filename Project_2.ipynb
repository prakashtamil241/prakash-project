# %% [markdown]
# <a href="https://colab.research.google.com/github/prakashtamil241/prakash-project/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_csv('project.csv')

df.head(10)
# Out:
#          Date             Politician       Party           Topic Sentiment  \
# 0  1975-02-22  Franklin D. Roosevelt  Democratic    civil rights  negative
# 1  1973-01-20              Joe Biden  Democratic  foreign policy   neutral
# 2  1945-10-07           Barack Obama  Democratic     environment  positive
# 3  1988-05-29        John F. Kennedy  Democratic  foreign policy  positive
# 4  1983-10-26           Barack Obama  Democratic    civil rights  negative
# 5  1998-02-28           Donald Trump  Republican  foreign policy   neutral
# 6  2023-02-11         George W. Bush  Republican  foreign policy  negative
# 7  1934-12-19           Barack Obama  Democratic        military  positive
# 8  2004-01-29        John F. Kennedy  Democratic  foreign policy  positive
# 9  1989-05-10           Barack Obama  Democratic  foreign policy   neutral
#
#                                        SpeechExcerpt
# 0  This is a negative statement about civil right...
# ...

# %%
df.sort_values(by='Date')
# Out:
#           Date             Politician       Party           Topic Sentiment  \
# 19  1931-07-09  Franklin D. Roosevelt  Democratic      healthcare  negative
# 33  1931-09-02          Ronald Reagan  Republican      healthcare  positive
# 30  1932-05-16           Barack Obama  Democratic  foreign policy  positive
# 7   1934-12-19           Barack Obama  Democratic        military  positive
# 87  1937-04-10              Joe Biden  Democratic       education  positive
# ..         ...                    ...         ...             ...       ...
# 18  2020-02-24              Joe Biden  Democratic       education  negative
# 84  2022-11-15        John F. Kennedy  Democratic     environment   neutral
# 6   2023-02-11         George W. Bush  Republican  foreign policy  negative
# 92  2023-04-13              Joe Biden  Democratic    civil rights  positive
# 66  2023-04-24        John F. Kennedy  Democratic       education   neutral
#
#                                         SpeechExcerpt
# ...

# %%
import matplotlib.pyplot as plt

df['Date'] = pd.to_datetime(df['Date'])
sentiment_trend = df.groupby(df['Date'].dt.year)['Sentiment'].value_counts().unstack().fillna(0)
sentiment_trend.plot(kind='line')
plt.title('Sentiment Trends Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Speeches')
plt.show()

# %%
df.groupby(['Party', 'Sentiment']).size()
# Out:
# Party       Sentiment
# Democratic  negative     15
#             neutral      19
#             positive     20
# Republican  negative     21
#             neutral      10
#             positive     15
# dtype: int64

# %%
df[df['Politician'] == 'Barack Obama']
# Out:
#          Date    Politician       Party           Topic Sentiment  \
# 2  1945-10-07  Barack Obama  Democratic     environment  positive
# 4  1983-10-26  Barack Obama  Democratic    civil rights  negative
# 7  1934-12-19  Barack Obama  Democratic        military  positive
# 9  1989-05-10  Barack Obama  Democratic  foreign policy   neutral
# 13 1969-11-14  Barack Obama  Democratic      healthcare  positive
# 20 2007-04-05  Barack Obama  Democratic       education  positive
# 23 1945-05-05  Barack Obama  Democratic       education   neutral
# 30 1932-05-16  Barack Obama  Democratic  foreign policy  positive
# 37 1952-05-10  Barack Obama  Democratic        military  positive
# 53 1973-04-02  Barack Obama  Democratic        military  negative
# 57 1943-02-08  Barack Obama  Democratic  foreign policy  negative
# 68 2002-08-02  Barack Obama  Democratic     environment  positive
# 71 1972-06-12  Barack Obama  Democratic       education  positive
# ...

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# negative    36
# positive    35
# neutral     29
# Name: count, dtype: int64
